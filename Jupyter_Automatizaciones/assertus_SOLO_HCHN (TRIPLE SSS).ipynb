# %% [markdown]
# En el siguiente informe logro determinar cuales son los encuentros hchn dependiendo el reporte que se haya realizado del software de facturacion HCHN, El reporte solo trae los ultimos encuentros de cada uno de los pacientes siempre y cuando hayan sido facturados por un diagnostico HCHN.

# %%
import pandas as pd 
import os.path

# %%
assertus = pd.read_excel (os.path.abspath ("./inputs/assertus_report.xlsx"), sheet_name = "GenericReport-CSV-(070820)  08-") 
hchn = pd.read_excel (os.path.abspath ("./inputs/HCHN ICD-10 Diagnoses.xlsx"), sheet_name = "HCHN Diagnoses") 
pd.options.display.max_columns = 80
pd.options.display.max_rows = 50

# %%
assertus_report1 = assertus [["sProcedureCode","dDateFrom","sCardContractNo", "Dx1", "Dx2", "Dx3", "Dx4", "Dx5", "Dx6", "Dx7", "Dx8", "Dx9", "Dx10", "Dx11","Dx12" ] ]
assertus_report1


#Utilizar solos los codigo de procedimiento que sean los siguientes 99441, 99442, 99443,99213, 99203 
assertus_report1 [assertus_report1.sProcedureCode.isin([99441, 99442, 99443,99213, 99203])]
assertus_report1 = assertus_report1 [assertus_report1.sProcedureCode.isin([99441, 99442, 99443,99213, 99203])]
assertus_report1
# Out:
#        sProcedureCode           dDateFrom sCardContractNo      Dx1    Dx2  \
# 221             99441 2020-03-19 09:12:20     80003140257    F84.9    NaN
# 224             99443 2020-03-25 07:11:15     80022757700    F41.9    NaN
# 225             99443 2020-03-16 07:11:15     80031304257    F33.2  F41.9
# 226             99443 2020-03-24 07:11:15     80033863571    F41.9  F33.2
# 227             99443 2020-04-21 07:20:38     80031304257    F33.2  F41.9
# ...               ...                 ...             ...      ...    ...
# 115296          99441 2020-06-24 07:12:09     80019620756    I11.9  E78.2
# 115310          99203 2020-06-23 07:12:09     80008269303    E03.9  K21.9
# 115314          99203 2020-06-23 07:12:09     80034396489      I10  B18.2
# 115316          99213 2020-06-19 07:12:09     80001841864  M25.562  G80.9
# 115322          99442 2020-06-22 07:12:09     80000165416      I10  E78.5
#
#             Dx3      Dx4    Dx5     Dx6  Dx7  Dx8  Dx9 Dx10 Dx11 Dx12
# ...

# %%
assertus_HCHN1 = assertus_report1.merge(hchn, how = "left", left_on = "Dx1", right_on = "Dx")
assertus_HCHN1 = assertus_HCHN1.rename(columns={"Dx" : "HDx1"})
assertus_HCHN1 = assertus_HCHN1["HDx1"]

# %%
assertus_HCHN2 = assertus_report1.merge(hchn, how = "left", left_on = "Dx2", right_on = "Dx")
assertus_HCHN2 = assertus_HCHN2.rename(columns={"Dx" : "HDx2"})
assertus_HCHN2 = assertus_HCHN2["HDx2"]

# %%
assertus_HCHN3 = assertus_report1.merge(hchn, how = "left", left_on = "Dx3", right_on = "Dx")
assertus_HCHN3 = assertus_HCHN3.rename(columns={"Dx" : "HDx3"})
assertus_HCHN3 = assertus_HCHN3["HDx3"]
assertus_HCHN3
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 16309        NaN
# 16310        NaN
# 16311        NaN
# 16312    J45.909
# 16313        NaN
# Name: HDx3, Length: 16314, dtype: object

# %%
assertus_HCHN4 = assertus_report1.merge(hchn, how = "left", left_on = "Dx4", right_on = "Dx")
assertus_HCHN4 = assertus_HCHN4.rename(columns={"Dx" : "HDx4"})
assertus_HCHN4 = assertus_HCHN4["HDx4"]

# %%
assertus_HCHN5 = assertus_report1.merge(hchn, how = "left", left_on = "Dx5", right_on = "Dx")
assertus_HCHN5 = assertus_HCHN5.rename(columns={"Dx" : "HDx5"})
assertus_HCHN5 = assertus_HCHN5["HDx5"]

# %%
assertus_HCHN6 = assertus_report1.merge(hchn, how = "left", left_on = "Dx6", right_on = "Dx")
assertus_HCHN6 = assertus_HCHN6.rename(columns={"Dx" : "HDx6"})
assertus_HCHN6 = assertus_HCHN6["HDx6"]

# %%
assertus_HCHN7 = assertus_report1.merge(hchn, how = "left", left_on = "Dx7", right_on = "Dx")
assertus_HCHN7 = assertus_HCHN7.rename(columns={"Dx" : "HDx7"})
assertus_HCHN7 = assertus_HCHN7["HDx7"]

# %%
assertus_HCHN8 = assertus_report1.merge(hchn, how = "left", left_on = "Dx8", right_on = "Dx")
assertus_HCHN8 = assertus_HCHN8.rename(columns={"Dx" : "HDx8"})
assertus_HCHN8 = assertus_HCHN8["HDx8"]

# %%
assertus_HCHN9 = assertus_report1.merge(hchn, how = "left", left_on = "Dx9", right_on = "Dx")
assertus_HCHN9 = assertus_HCHN9.rename(columns={"Dx" : "HDx9"})
assertus_HCHN9 = assertus_HCHN9["HDx9"]

# %%
assertus_HCHN10 = assertus_report1.merge(hchn, how = "left", left_on = "Dx10", right_on = "Dx")
assertus_HCHN10 = assertus_HCHN10.rename(columns={"Dx" : "HDx10"})
assertus_HCHN10 = assertus_HCHN10["HDx10"]

# %%
assertus_HCHN11 = assertus_report1.merge(hchn, how = "left", left_on = "Dx11", right_on = "Dx")
assertus_HCHN11 = assertus_HCHN11.rename(columns={"Dx" : "HDx11"})
assertus_HCHN11 = assertus_HCHN11["HDx11"]

# %%
assertus_HCHN12 = assertus_report1.merge(hchn, how = "left", left_on = "Dx12", right_on = "Dx")
assertus_HCHN12 = assertus_HCHN12.rename(columns={"Dx" : "HDx12"})
assertus_HCHN12 = assertus_HCHN12[["HDx12", "sCardContractNo", "dDateFrom", "sProcedureCode"]]

# %%
assertus_HCHN = pd.concat([assertus_HCHN1, assertus_HCHN2, assertus_HCHN3, assertus_HCHN4, assertus_HCHN5, assertus_HCHN6, assertus_HCHN7, assertus_HCHN8, assertus_HCHN9, assertus_HCHN10, assertus_HCHN11, assertus_HCHN12], axis = 1)
mask1 = assertus_HCHN[["HDx1", "HDx2", "HDx3", "HDx4", "HDx5", "HDx6", "HDx7", "HDx8", "HDx9", "HDx10", "HDx11","HDx12" ]].dropna(how = "all")
assertus_HCHN = mask1.merge(assertus_HCHN, how = "left", left_index = True, right_index = True)
assertus_HCHN = assertus_HCHN.drop(columns=["HDx1_x", "HDx2_x", "HDx3_x", "HDx4_x", "HDx5_x", "HDx6_x", "HDx7_x", "HDx8_x", "HDx9_x", "HDx10_x", "HDx11_x", "HDx12_x"])
assertus_HCHN = assertus_HCHN [["sCardContractNo","dDateFrom","sProcedureCode","HDx1_y", "HDx2_y", "HDx3_y", "HDx4_y", "HDx5_y", "HDx6_y","HDx7_y", "HDx8_y", "HDx9_y", "HDx10_y", "HDx11_y", "HDx12_y"]]

# %%
assertus_HCHN["orden"] = assertus_HCHN.groupby("sCardContractNo")["dDateFrom"].rank(method="dense", ascending=False).astype(int)
assertus_HCHN = assertus_HCHN[assertus_HCHN["orden"] == 1]
assertus_HCHN
# Out:
#       sCardContractNo           dDateFrom sProcedureCode HDx1_y HDx2_y  \
# 29        80010340499 2020-01-23 08:12:00          99213    NaN    NaN
# 48        80021159064 2020-01-14 14:11:56          99203  I11.9    NaN
# 57        80006434303 2020-01-23 09:06:16          99213  I11.9    NaN
# 63        80005151428 2020-01-16 08:08:14          99213    NaN    NaN
# 71        80004424256 2020-01-20 08:06:27          99213    NaN    NaN
# ...               ...                 ...            ...    ...    ...
# 16307     80000020192 2020-06-17 10:26:48          99441  I11.9    NaN
# 16309     80019620756 2020-06-24 07:12:09          99441  I11.9    NaN
# 16311     80034396489 2020-06-23 07:12:09          99203    I10    NaN
# 16312     80001841864 2020-06-19 07:12:09          99213    NaN    NaN
# 16313     80000165416 2020-06-22 07:12:09          99442    I10    NaN
#
#         HDx3_y HDx4_y HDx5_y HDx6_y HDx7_y HDx8_y HDx9_y HDx10_y HDx11_y  \
# ...

# %%
#pd.melt(concat1,id_vars=["sCardContractNo"])
#concat2 = concat2.drop(columns=["variable"])
#concat2 = concat2.dropna()
#concat2 = concat2.groupby('sCardContractNo')['value'].apply(list)

# %%
#Pasando el reporte Solo HCHN a EXCEL 
assertus_HCHN.to_excel("outputs\Reporte de solo los pacientes con HCHN.xlsx")

# %%
EBH = pd.read_excel (os.path.abspath ("./inputs/EBH.xlsx"), sheet_name = "Sheet1") 
EBH
# Out:
#                 PMG-A status Month_Report  carrier      mem_mpi hchn_category  \
# 0    EAST BEST HEALTH  ADDED   2020-06-01       13  80000045741      Diabetes
# 1    EAST BEST HEALTH  ADDED   2020-06-01       13  80000165416    Low Cardio
# 2    EAST BEST HEALTH  ADDED   2020-06-01       13  80000195877      Diabetes
# 3    EAST BEST HEALTH  ADDED   2020-06-01       13  80000208938    Low Cardio
# 4    EAST BEST HEALTH  ADDED   2020-06-01       13  80000209748    Low Cardio
# ..                ...    ...          ...      ...          ...           ...
# 615  EAST BEST HEALTH  ADDED   2020-06-01       13  80034248749     Pulmonary
# 616  EAST BEST HEALTH  ADDED   2020-06-01       13  80034282858      Diabetes
# 617  EAST BEST HEALTH  ADDED   2020-06-01       13  80034286926    Low Cardio
# 618  EAST BEST HEALTH  ADDED   2020-06-01       13  80034291792      Diabetes
# 619  EAST BEST HEALTH  ADDED   2020-06-01       13  80034302328   High Cardio
#
# ...

# %%
assertus_HCHN_merge = assertus_HCHN [["dDateFrom", "sCardContractNo", "HDx1_y", "HDx2_y", "HDx3_y", "HDx4_y", "HDx5_y", "HDx6_y","HDx7_y", "HDx8_y", "HDx9_y", "HDx10_y", "HDx11_y", "HDx12_y"]]

# %%
union_assertusytriplesss = EBH.merge(assertus_HCHN_merge, how = "left", left_on = "mem_mpi", right_on = "sCardContractNo")
union_assertusytriplesss
# Out:
#                 PMG-A status Month_Report  carrier      mem_mpi hchn_category  \
# 0    EAST BEST HEALTH  ADDED   2020-06-01       13  80000045741      Diabetes
# 1    EAST BEST HEALTH  ADDED   2020-06-01       13  80000165416    Low Cardio
# 2    EAST BEST HEALTH  ADDED   2020-06-01       13  80000195877      Diabetes
# 3    EAST BEST HEALTH  ADDED   2020-06-01       13  80000208938    Low Cardio
# 4    EAST BEST HEALTH  ADDED   2020-06-01       13  80000209748    Low Cardio
# ..                ...    ...          ...      ...          ...           ...
# 615  EAST BEST HEALTH  ADDED   2020-06-01       13  80034248749     Pulmonary
# 616  EAST BEST HEALTH  ADDED   2020-06-01       13  80034282858      Diabetes
# 617  EAST BEST HEALTH  ADDED   2020-06-01       13  80034286926    Low Cardio
# 618  EAST BEST HEALTH  ADDED   2020-06-01       13  80034291792      Diabetes
# 619  EAST BEST HEALTH  ADDED   2020-06-01       13  80034302328   High Cardio
#
# ...

# %%
union_assertusytriplesss.to_excel("outputs\Reporte Triple SSS con los ultimos encuentros HCHN.xlsx")
