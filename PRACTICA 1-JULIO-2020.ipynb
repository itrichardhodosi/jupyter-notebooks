# %%
import pandas as pd
import os.path

# %% [markdown]
# # Practica Miercoles 1 de Julio 2020

# %%
data1 = pd.read_excel(os.path.abspath(".\inputs\EBH.xlsx"), sheet_name="Sheet1")

# %%
#viendo primero 5 valores del fata frame 
data1.head()
# Out:
#               PMG-A status  ... Telefónico  Face Time o Video llamada
# 0  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 1  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 2  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 3  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 4  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
#
# [5 rows x 40 columns]

# %%
data1.tail()
# Out:
#                  PMG-A status  ... Telefónico  Face Time o Video llamada
# 4187  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 4188  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 4189  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 4190  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
# 4191  EAST BEST HEALTH  ADDED  ...        NaN                        NaN
#
# [5 rows x 40 columns]

# %%
#mostrando informacion importante del data frame (tipos de datos y cantidades de datos en cada columna )
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4192 entries, 0 to 4191
# Data columns (total 40 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   PMG-A                                                                         4192 non-null   object
#  1   status                                                                        4192 non-null   object
#  2   Month_Report                                                                  4192 non-null   datetime64[ns]
#  3   carrier                                                                       4192 non-null   int64
#  4   mem_mpi                                                                       4192 non-null   int64
#  5   hchn_category                                                                 4192 non-null   object
#  6   program                                                                       4192 non-null   object
#  7   rate_cell                                                                     4192 non-null   int64
#  8   actuary                                                                       4192 non-null   object
#  9   End_Month                                                                     4192 non-null   int64
#  10  Elegible Y/N as of June 18, 2020                                              4192 non-null   object
#  11  MPI                                                                           4192 non-null   int64
#  12  Member Fullname                                                               4192 non-null   object
#  13  Gender                                                                        4192 non-null   object
#  14  DOB                                                                           4192 non-null   datetime64[ns]
#  15  Member Phone                                                                  117 non-null    object
#  16  Member e-mail                                                                 114 non-null    object
#  17  Member Phyaddr1                                                               4192 non-null   object
#  18  Member Phyaddr2                                                               2262 non-null   object
#  19  Member Phycity                                                                4192 non-null   object
#  20  Member Phystate                                                               4192 non-null   object
#  21  Member Phyzip                                                                 4192 non-null   int64
#  22  PCP NPI                                                                       4192 non-null   int64
#  23  PCP_Name                                                                      4192 non-null   object
#  24  PCP_Specialty                                                                 4192 non-null   object
#  25  PMG Number                                                                    4192 non-null   object
#  26  PMG NAME                                                                      4192 non-null   object
#  27  RxProfile                                                                     49 non-null     object
#  28  Perfil Rx ID                                                                  117 non-null    float64
#  29  Most Recent Encounter.Dosfrom                                                 83 non-null     datetime64[ns]
#  30  Most Recent Encounter.Servcode                                                83 non-null     object
#  31  Most Recent Encounter Rendering prov Npi                                      83 non-null     float64
#  32  Most Recent Encounter Rendering prov Fullname                                 83 non-null     object
#  33  Status of Payment 99211 as of June 18, 2020 (Paid/Denied/Pending to Process)  549 non-null    object
#  34  Billing Provider-One TSH                                                      550 non-null    object
#  35  ICN (Claim Number) - One TSH                                                  4192 non-null   object
#  36  Fecha en que GRUPO logró contacto y coordinación de cita con PCP              0 non-null      float64
#  37  Fecha en que ocurrió el Encuentro                                             266 non-null    datetime64[ns]
#  38  Telefónico                                                                    0 non-null      float64
#  39  Face Time o Video llamada                                                     0 non-null      float64
# dtypes: datetime64[ns](4), float64(5), int64(7), object(24)
# memory usage: 1.3+ MB

# %%
#Viendo informacion estadistica del data frame completo y especificando columna
data1.describe()
data1["carrier"].describe()
# Out:
# count    4192.0
# mean       13.0
#           ...
# 75%        13.0
# max        13.0
# Name: carrier, Length: 8, dtype: float64

# %%
#Contando valores dentro de una columna
data1["PCP_Name"].value_counts()
# Out:
# QUILES COLON, LAURA M         131
# HERNANDEZ PASTRANA, MONICA    131
#                              ...
# PEREZ BRIONES, JULIO A          1
# SERRANO RAMOS, RONALD           1
# Name: PCP_Name, Length: 221, dtype: int64

# %%
#Cambiando datos de un tipo a otro (En este caso de entero a decimal)
data1["carrier"].astype("float")
# Out:
# 0       13.0
# 1       13.0
#         ...
# 4190    13.0
# 4191    13.0
# Name: carrier, Length: 4192, dtype: float64

# %%
#Escogiendo cuantas columnas y filas presentar 
pd.options.display.max_columns = 30
pd.options.display.max_rows = 5

# %%
#Viendo Cantidad de Veces que se repite un valor 
data1.dropna(subset= ["ICN (Claim Number) - One TSH"])
# Out:
#                  PMG-A status Month_Report  carrier      mem_mpi  \
# 0     EAST BEST HEALTH  ADDED   2020-06-01       13  80000013547
# 1     EAST BEST HEALTH  ADDED   2020-06-01       13  80000023718
# ...                ...    ...          ...      ...          ...
# 4190  EAST BEST HEALTH  ADDED   2020-06-01       13  80034381686
# 4191  EAST BEST HEALTH  ADDED   2020-06-01       13  80034382526
#
#      hchn_category       program  rate_cell actuary  End_Month  \
# 0         Diabetes  Commonwealth         11       Y     202008
# 1        Pulmonary      Medicaid         36       Y     202102
# ...            ...           ...        ...     ...        ...
# 4190    Low Cardio      Medicaid         28       Y     202103
# 4191        Cancer      Medicaid         27       Y     202104
#
#      Elegible Y/N as of June 18, 2020          MPI  \
# 0                              Active  80000013547
# 1                              Active  80000023718
# ...                               ...          ...
# 4190                           Active  80034381686
# 4191                           Active  80034382526
#
#                   Member Fullname Gender        DOB  ... PMG Number  \
# 0           PINERO NEGRON, LUIS M      M 1962-02-05  ...  PMG-07602
# 1     DIAZ CARRASQUILLO, HECTOR N      M 1989-07-02  ...  PMG-90766
# ...                           ...    ...        ...  ...        ...
# 4190    SANTIAGO GONZALEZ, EVELYN      F 1966-02-01  ...  PMG-07602
# 4191       LOPEZ TORRES, VIVIAN I      F 1978-01-15  ...  PMG-07602
#
#                                                PMG NAME RxProfile  \
# 0     INTERNAL MEDICINE CANOVANAS GROUP CORP,  PMG-0...       NaN
# 1                        E66-TIGER MED CORP,  PMG-90766       NaN
# ...                                                 ...       ...
# 4190  INTERNAL MEDICINE CANOVANAS GROUP CORP,  PMG-0...       NaN
# 4191  INTERNAL MEDICINE CANOVANAS GROUP CORP,  PMG-0...       NaN
#
#      Perfil Rx ID Most Recent Encounter.Dosfrom  \
# 0             NaN                           NaT
# 1             NaN                           NaT
# ...           ...                           ...
# 4190          NaN                           NaT
# 4191          NaN                           NaT
#
#      Most Recent Encounter.Servcode  Most Recent Encounter Rendering prov Npi  \
# 0                               NaN                                       NaN
# 1                               NaN                                       NaN
# ...                             ...                                       ...
# 4190                            NaN                                       NaN
# 4191                            NaN                                       NaN
#
#       Most Recent Encounter Rendering prov Fullname  \
# 0                                               NaN
# 1                                               NaN
# ...                                             ...
# 4190                                            NaN
# 4191                                            NaN
#
#      Status of Payment 99211 as of June 18, 2020 (Paid/Denied/Pending to Process)  \
# 0                                                DENIED
# 1                                                   NaN
# ...                                                 ...
# 4190                                                NaN
# 4191                                                NaN
#
#          Billing Provider-One TSH ICN (Claim Number) - One TSH  \
# 0     INTERNAL MEDICINE CANOVANAS                  20142E42533
# 1                             NaN              Dont ICN Number
# ...                           ...                          ...
# 4190       GOMEZ SALDANA, WILFRED              Dont ICN Number
# 4191                          NaN              Dont ICN Number
#
#      Fecha en que GRUPO logró contacto y coordinación de cita con PCP  \
# 0                                                   NaN
# 1                                                   NaN
# ...                                                 ...
# 4190                                                NaN
# 4191                                                NaN
#
#      Fecha en que ocurrió el Encuentro  Telefónico Face Time o Video llamada
# 0                                  NaT         NaN                       NaN
# 1                                  NaT         NaN                       NaN
# ...                                ...         ...                       ...
# 4190                               NaT         NaN                       NaN
# 4191                               NaT         NaN                       NaN
#
# [4192 rows x 40 columns]

# %%
#Rellenando espacios vacios de las columnas con Argumentos puestos por mi
data1["ICN (Claim Number) - One TSH"].fillna("Dont ICN Number", inplace = True)

# %%
#con eso puedo ver cuantos valores de la columna medicos no se repiten osea SON UNICOS 
data1["PCP_Name"].nunique()
# Out:
# 221

# %%
#Viendo los nombres de los pacientes de Z-A debido a la funcion ascending en false
data1.sort_values("Member Fullname", ascending= False)
# Out:
#                  PMG-A status Month_Report  carrier      mem_mpi  \
# 3887  EAST BEST HEALTH  ADDED   2020-06-01       13  80033704430
# 221   EAST BEST HEALTH  ADDED   2020-06-01       13  80002454826
# ...                ...    ...          ...      ...          ...
# 1780  EAST BEST HEALTH  ADDED   2020-06-01       13  80015941126
# 885   EAST BEST HEALTH  ADDED   2020-06-01       13  80007473560
#
#      hchn_category   program  rate_cell actuary  End_Month  \
# 3887      Diabetes  Medicaid         28       Y     202012
# 221       Diabetes  Medicaid         28       Y     202102
# ...            ...       ...        ...     ...        ...
# 1780    Low Cardio  Medicaid         28       Y     202010
# 885      Pulmonary  Medicaid         36       Y     202010
#
#      Elegible Y/N as of June 18, 2020          MPI          Member Fullname  \
# 3887                           Active  80033704430            ZENO, AUREA L
# 221                            Active  80002454826   ZELEDON ORTIZ, MARIA A
# ...                               ...          ...                      ...
# 1780                           Active  80015941126  ABADIA TORRES, HECTOR L
# 885                            Active  80007473560      ABADIA COLON, LUZ M
#
#      Gender        DOB  ... PMG Number                         PMG NAME  \
# 3887      F 1961-01-06  ...  PMG-07620  NEOMED CENTERS, INC,  PMG-07620
# 221       F 1966-04-13  ...  PMG-07620  NEOMED CENTERS, INC,  PMG-07620
# ...     ...        ...  ...        ...                              ...
# 1780      M 1971-01-21  ...  PMG-90766   E66-TIGER MED CORP,  PMG-90766
# 885       F 1958-06-08  ...  PMG-90766   E66-TIGER MED CORP,  PMG-90766
#
#      RxProfile Perfil Rx ID Most Recent Encounter.Dosfrom  \
# 3887       NaN          NaN                           NaT
# 221        NaN          NaN                           NaT
# ...        ...          ...                           ...
# 1780       NaN          NaN                           NaT
# 885        NaN          NaN                           NaT
#
#      Most Recent Encounter.Servcode  Most Recent Encounter Rendering prov Npi  \
# 3887                            NaN                                       NaN
# 221                             NaN                                       NaN
# ...                             ...                                       ...
# 1780                            NaN                                       NaN
# 885                             NaN                                       NaN
#
#       Most Recent Encounter Rendering prov Fullname  \
# 3887                                            NaN
# 221                                             NaN
# ...                                             ...
# 1780                                            NaN
# 885                                             NaN
#
#      Status of Payment 99211 as of June 18, 2020 (Paid/Denied/Pending to Process)  \
# 3887                                                NaN
# 221                                                 NaN
# ...                                                 ...
# 1780                                                NaN
# 885                                                 NaN
#
#      Billing Provider-One TSH ICN (Claim Number) - One TSH  \
# 3887                      NaN              Dont ICN Number
# 221                       NaN              Dont ICN Number
# ...                       ...                          ...
# 1780                      NaN              Dont ICN Number
# 885                       NaN              Dont ICN Number
#
#      Fecha en que GRUPO logró contacto y coordinación de cita con PCP  \
# 3887                                                NaN
# 221                                                 NaN
# ...                                                 ...
# 1780                                                NaN
# 885                                                 NaN
#
#      Fecha en que ocurrió el Encuentro  Telefónico Face Time o Video llamada
# 3887                               NaT         NaN                       NaN
# 221                                NaT         NaN                       NaN
# ...                                ...         ...                       ...
# 1780                               NaT         NaN                       NaN
# 885                                NaT         NaN                       NaN
#
# [4192 rows x 40 columns]
