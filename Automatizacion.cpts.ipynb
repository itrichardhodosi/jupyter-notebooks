# %%
import pandas as pd
import os.path

# %%
data1 = pd.read_excel(os.path.abspath(".\inputs\probando.xlsx"), sheet_name="Sheet1")

# %%
pd.options.display.max_columns = 80
pd.options.display.max_rows = 5

# %%
data1 [data1.sProcedureCode.isin([99441, 99442, 99443,99213])]
# Out:
#       sProvBillingNo sLastName        sNPI sRecordNo  \
# 44              ARSE      ARSE  1720395130     11259
# 47              ARSE      ARSE  1720395130   P-13508
# ...              ...       ...         ...       ...
# 53680           ARSE      ARSE  1720395130     13020
# 53685           ARSE      ARSE  1720395130     13221
#
#                         PatName        DOB      sSocSec  \
# 44         LOPEZ SARRIA  DINUEL 2015-11-03
# 47           ROSA SANTANA  JOHN 2004-02-26
# ...                         ...        ...          ...
# 53680  MARTINEZ ESQUILIN  ANGEL 2001-01-30
# 53685      CRUZ RODRIGUEZ  LUIS 1962-07-15
#
#                            sPAddressLine1 sPAddressLine2        PCity PState  \
# 44                     EXT ROY 97 CALLE 1            NaN      Humacao     PR
# 47     URB JARDINES DE CEIBA K 7 CALLE 10            NaN        Ceiba     PR
# ...                                   ...            ...          ...    ...
# 53680             PO BOX 93 BO RIO BLANCO            NaN  Rio Blanco      PR
# 53685                         PO BOX 1956            NaN     YABUCOA      PR
#
#       sPPostalCode sInsuranceNo                         InsName  \
# 44             791          APS  APS HEALTHCARE PUERTO RICO INC
# 47             735          APS  APS HEALTHCARE PUERTO RICO INC
# ...            ...          ...                             ...
# 53680          744    SSS VITAL                  TRIPLE S VITAL
# 53685          767    SSS VITAL                  TRIPLE S VITAL
#
#       sCardContractNo sProcedureCode sDxID1  sDxID2  sDxID3  sDxID4  \
# 44        80003140257          99441  F84.9     NaN     NaN     NaN
# 47        80022757700          99443  F41.9     NaN     NaN     NaN
# ...               ...            ...    ...     ...     ...     ...
# 53680     80012319277          99213  R76.8     NaN     NaN     NaN
# 53685     80013327199          99213  E78.5     NaN     NaN     NaN
#
#        sClaimNumber           dDateFrom    Dx1      Dx2    Dx3  Dx4  Dx5  Dx6  \
# 44           115390 2020-03-19 09:12:20  F84.9      NaN    NaN  NaN  NaN  NaN
# 47           115791 2020-03-25 07:11:15  F41.9      NaN    NaN  NaN  NaN  NaN
# ...             ...                 ...    ...      ...    ...  ...  ...  ...
# 53680        120509 2020-06-17 07:12:09  R76.8    F41.0    NaN  NaN  NaN  NaN
# 53685        120511 2020-06-17 07:12:09  E78.5  F17.200  F33.3  NaN  NaN  NaN
#
#        Dx7  Dx8  Dx9 Dx10 Dx11 Dx12
# 44     NaN  NaN  NaN  NaN  NaN  NaN
# 47     NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...
# 53680  NaN  NaN  NaN  NaN  NaN  NaN
# 53685  NaN  NaN  NaN  NaN  NaN  NaN
#
# [8866 rows x 34 columns]

# %%
data1 = data1 [data1.sProcedureCode.isin([99441, 99442, 99443,99213])]

# %%
data1.to_excel("outputs\probando1.xlsx")

# %%
data1 (data1 ["sProcedureCode"] ["PCity"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-f20f52dbf212> in <module>
# ----> 1 data1 (data1 ["sProcedureCode"] ["PCity"])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'PCity'
